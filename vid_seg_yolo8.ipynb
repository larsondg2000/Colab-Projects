# %% [markdown]
# <a href="https://colab.research.google.com/github/larsondg2000/Colab-Projects/blob/main/vid_seg_yolo8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Connect Google Colab with Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Install Yolo8**
#
# *   yolov8 Github: https://github.com/ultralytics/ultralytics
# *   yolov8 docs: https://docs.ultralytics.com/

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 61.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 60.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 73.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.36 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %% [markdown]
# # YOLO8 Training Hyperparameters
#
#
#
# *   task = detect or segment
# *   mode = train, val
# *   model = path to model file i.e. yolov8n.pt, yolov8n.yaml
# *   data = path to datafile dataset.yaml
# *   epochs = number of training epochs
# *   imgsz = size of input images (int)
# *   batch = number of images perf batch
# *   project = project training results saving path
# *   name = experimnet name

# %%
! yolo task=segment \
mode=train \
model=yolov8n.pt \
data=/content/drive/MyDrive/VehicleInstanceSegmentation/dataset.yaml \
epochs=20 \
imgsz=640 \
batch=5 \
project=/content/drive/MyDrive/VehicleInstanceSegmentation/TrainingResults\
name=Vehic
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 29.5MB/s]
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.36 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Inference using trained YOLO8

# %% [markdown]
# Instance Segmentation on the Test Images

# %%
# !yolo task=segment\
mode=predict\
model=/content/drive/MyDrive/VehicleInstanceSegmentation/TrainingResults/Vehic/weights/best.pt\
conf=0.55\
source=/content/drive/MyDrive/VehicleInstanceSegmentation/data/test/images
# Out:
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.36 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/7 /content/drive/MyDrive/VehicleInstanceSegmentation/data/test/images/image_13_png.rf.c45bccb81a3cb2297a376b52d803c0ac.jpg: 640x640 2 cars, 5 motorbike-bikes, 8.5ms
# image 2/7 /content/drive/MyDrive/VehicleInstanceSegmentation/data/test/images/image_24_png.rf.a7cb8c3436997493e456167814576d3b.jpg: 640x640 9 motorbike-bikes, 11.5ms
# image 3/7 /content/drive/MyDrive/VehicleInstanceSegmentation/data/test/images/image_25_png.rf.b01f11f226a1648f82a5b7c4aa1999a3.jpg: 640x640 9 cars, 7 motorbike-bikes, 19.1ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/VehicleInstanceSegmentation/SegmentationResults/

# %% [markdown]
# Instance Segmentation on Videos

# %%
# !yolo task=segment\
mode=predict\
model=/content/drive/MyDrive/VehicleInstanceSegmentation/TrainingResults/Vehic/weights/best.pt\
conf=0.55\
source=/content/drive/MyDrive/VehicleInstanceSegmentation/TestVideos/
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/2 (frame 229/716) /content/drive/MyDrive/VehicleInstanceSegmentation/TestVideos/Cars On Road.mp4: 384x640 7 cars, 11.2ms
# video 1/2 (frame 230/716) /content/drive/MyDrive/VehicleInstanceSegmentation/TestVideos/Cars On Road.mp4: 384x640 8 cars, 8.5ms
# video 1/2 (frame 231/716) /content/drive/MyDrive/VehicleInstanceSegmentation/TestVideos/Cars On Road.mp4: 384x640 7 cars, 7.7ms
# video 1/2 (frame 232/716) /content/drive/MyDrive/VehicleInstanceSegmentation/TestVideos/Cars On Road.mp4: 384x640 7 cars, 8.3ms
# video 1/2 (frame 233/716) /content/drive/MyDrive/VehicleInstanceSegmentation/TestVideos/Cars On Road.mp4: 384x640 8 cars, 8.1ms
# video 1/2 (frame 234/716) /content/drive/MyDrive/VehicleInstanceSegmentation/TestVideos/Cars On Road.mp4: 384x640 8 cars, 8.7ms
# video 1/2 (frame 235/716) /content/drive/MyDrive/VehicleInstanceSegmentation/TestVideos/Cars On Road.mp4: 384x640 7 cars, 7.8ms
# ...

# %%
# !cp -r /content/runs/detect/predict2 /content/drive/MyDrive/VehicleInstanceSegmentation/SegmentationResults/
